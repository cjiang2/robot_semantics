# %% [markdown]
# ## Inference One Video and Visualize the Knowledge Graph.
# Fast Demo: Load processed clips and do not host CNN.

# %%
import base64
import os
import sys
import pickle

import cv2
from PIL import Image
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib inline

from IPython.display import display
from IPython.display import HTML
from IPython.display import Javascript

# Root directory of the project
ROOT_DIR = os.path.abspath("../../../")

# Import rs utils
sys.path.append(ROOT_DIR)  # To find local version of the library
from rs.config import Config
from rs.models import *
from rs import utils
from rs import visualize
from rs.datasets import loader

# %%
# Configuration for hperparameters
class InferenceConfig(Config):
    """Configuration for training with RS-RGBD.
    """
    NAME = 'v2l_RS-RGBD'
    MODE = 'eval'
    ROOT_DIR = ROOT_DIR
    CHECKPOINT_PATH = os.path.join(ROOT_DIR, 'checkpoints')
    DATASET_PATH = os.path.join(ROOT_DIR, 'data', 'RS-RGBD')
    
    ### ------------ Modify params here ------------ ###
    BACKBONE = 'resnet50'
    LOAD_CNN = True
    WEIGHTS_PATH = os.path.join(ROOT_DIR, 'checkpoints', 'weights', '{}.pth'.format(BACKBONE))
    CHECKPOINT_FILE = os.path.join(CHECKPOINT_PATH, 'saved', 'v2l_epoch_trained.pth')
    TASK = 'eval_wam_grasp_pour'
    VIDEO_NAME = 'wam_unknown_water_plasticbottle1_glasscup3'
    VIDEO_PATH = os.path.join(DATASET_PATH,
                              TASK,
                              VIDEO_NAME, VIDEO_NAME)
    UPSAMPLE_METHOD = 'pyramid'
    ### ------------ End of Modification ----------- ###
# Out:
# Video path: /home/ubuntu/Desktop/robot_semantics/datasets/RS-RGBD/WAM_Evaluation/wam_unknown_milk_milkcan2_mug6
#
# Configurations:
# ------------------------------
# BACKBONE                       {'resnet50': 2048}
# BATCH_SIZE                     16
# CHECKPOINT_FILE                /home/ubuntu/Desktop/robot_semantics/checkpoints/saved/v2c_epoch_95.pth
# CHECKPOINT_PATH                /home/ubuntu/Desktop/robot_semantics/checkpoints
# DATASET_PATH                   /home/ubuntu/Desktop/robot_semantics/datasets/RS-RGBD
# DISPLAY_EVERY                  20
# EMBED_SIZE                     512
# END_WORD                       <eos>
# FREQUENCY                      None
# LEARNING_RATE                  0.0001
# MAXLEN                         15
# MODE                           test
# NAME                           v2c_RS-RGBD
# NUM_EPOCHS                     150
# ONTO_FILE                      /home/ubuntu/Desktop/robot_semantics/datasets/RS-RGBD/object_onto.owl
# RETRIEVAL_LIMIT                15
# ROOT_DIR                       /home/ubuntu/Desktop/robot_semantics
# SAVE_EVERY                     5
# SETTINGS                       ['Evaluation', 'WAM_Evaluation']
# START_WORD                     <sos>
# TEACHER_FORCING_RATIO          1.0
# UNITS                          512
# UNK_WORD                       None
# USE_BIAS_VECTOR                True
# VIDEO_NAME                     wam_unknown_milk_milkcan2_mug6
# VOCAB_SIZE                     39
# WINDOW_SIZE                    30
# WORKERS                        12
#
# No. clips to evaluate: 111 111

# %% [markdown]
# ## Some Helper Functions
# Helpers to generate clip, visualize attention, etc.

# %%
def init_model(config, 
               vocab,
               CHECKPOINT_FILE):
    # --------------------
    # Setup and build video2lang training inference
    v2l_model = Video2Lang(config, vocab)
    v2l_model.build(None)

    # Load back weights
    v2l_model.load_weights(CHECKPOINT_FILE)
    return v2l_model

def load_video(video_path, 
               f_format='%d_rgb.png'):
    """OpenCV video stream wrapper to collect all frames.
    """
    src = os.path.join(video_path, f_format)
    cap = cv2.VideoCapture(src)
    frames = []
    while True:
        ret, frame = cap.read()
        if frame is not None:
            frames.append(frame)
        else:
            break
    cap.release()
    return frames

def preprocess_clip(clip):
    """Wrapper func to preprocess a clip.
    """
    clip = [loader.transforms_data(Image.fromarray(cv2.cvtColor(x, cv2.COLOR_BGR2RGB))) for x in clip]
    return torch.stack(clip)

def generate_clips(frames, 
                   config):
    """Generate clips using video stream object.
    """
    stream = utils.StreamSimple(window_size=config.WINDOW_SIZE)
    clips = []
    indices = []
    for i, frame in enumerate(frames):
        stream.add_frame(frame)
        clip = stream.get_clip()
        if clip is not None:
            clip = preprocess_clip(clip)
            clips.append(clip)
            start_index = i - config.WINDOW_SIZE + 1
            indices.append((start_index, i))

    # Force retrieve the last clip
    clip = stream.get_clip(forced_retrieve=True)
    clip = preprocess_clip(clip)
    clips.append(clip)
    start_index = i - config.WINDOW_SIZE + 1
    indices.append((start_index, i))
    return clips, indices

def show_video(video_path):
    """Display an mp4 video in jupyter.
    """
    mp4 = open(video_path, 'rb').read()
    data_url = 'data:video/mp4;base64,' + base64.b64encode(mp4).decode()
    return HTML("""<video width=600 controls>
                <source src="%s" type="video/mp4"></video>
                """ % data_url)

def show_clip(frames,
              interval=30,
              plot_score=True,
              fps=10):
    tmp_path = 'output.mp4'
    
    num_frames = len(frames)
    fig, ax = plt.subplots(ncols=1, nrows=1)
    im0 = ax.imshow(frames[0])
    
    def update(i):
        im0.set_data(frames[i])
        ax.grid(False)
        ax.set_xticks([])
        ax.set_yticks([])
        plt.tight_layout()

    anim = FuncAnimation(fig,
                         update,
                         frames=num_frames,
                         interval=interval,
                         blit=False)
    anim.save(tmp_path, fps=fps)
    plt.close()
    return show_video(tmp_path)

# %% [markdown]
# ## Inference
# Test the inference of video2command model.

# %%
# Setup configuration class
config = InferenceConfig()

# Load v2l model
vocab = pickle.load(open(os.path.join(config.CHECKPOINT_PATH, 'vocab.pkl'), 'rb'))
config.VOCAB_SIZE = len(vocab)
v2l_model = init_model(config, vocab, config.CHECKPOINT_FILE)
config.display()
# Out:
# Loading saved model /home/ubuntu/Desktop/robot_semantics/checkpoints/saved/v2c_epoch_95.pth...
# Loading...
# Model loaded.
# Model loading success.
# Done collection.
# 111 111 111

# %%
# Collect video and generate clips
print('Loading video...')
frames = load_video(config.VIDEO_PATH)
print('No. frames:', len(frames), frames[0].shape)

print('Generating clips...')
clips, indices = generate_clips(frames, config)
print("No. clips:", len(clips))

# %%
# State the clip index to be used
### ------------ Modify params here ------------ ###
idx = 54
### ------------ End of Modification ----------- ###

clip, indices_clip = clips[idx], indices[idx]
frames_clip = frames[indices_clip[0]:indices_clip[1]]
print('Clip Indices:', indices_clip)

# Inference START HERE
clip = clip.to(v2l_model.device)
S, alphas = v2l_model.predict(clip)

# Collect result to CPU
S = S.cpu().numpy()[0]
alphas = alphas[0]
img_shape = frames_clip[0].shape[:2]
text = utils.sequence_to_text(S, vocab)
# Out:
# Video: wam_unknown_milk_milkcan2_mug6
# Starting at 870, ending at 899...
# Ground-truth Command: wamarm hold milk_can
# Prediction Command: wamarm hold milk_can

# %% [markdown]
# ## Visual Attention
# Visualize generated attention maps.

# %%
# Visualize current attention maps and command language
plots = visualize.display_video(frames_clip, 
                                [text for i in range(len(frames_clip))], 
                                alphas,
                                show_plot=False,
                                upsample_method=config.UPSAMPLE_METHOD)
print("Predicted Command: {}".format(text))
show_clip(plots)

# %% [markdown]
# ## Ontology & Visualization
# Here, we use the dynamic command sentence as the base knowledge graph. We loop through each word tokens(entities), retrieving known external knowledge stored inside a static ontology.

# %%
# --------------------
# Init ontology model
onto = utils.init_onto(config.ONTO_FILE)
# Out:
# Loaded owl file at: file:///home/ubuntu/Desktop/robot_semantics/datasets/RS-RGBD/object_onto.owl
# * Owlready2 * Running HermiT...
#     java -Xmx2000M -cp /usr/local/lib/python3.6/dist-packages/owlready2/hermit:/usr/local/lib/python3.6/dist-packages/owlready2/hermit/HermiT.jar org.semanticweb.HermiT.cli.CommandLine -c -O -D -I file:////tmp/tmpntcvg5lq
# * Owlready2 * HermiT took 0.8706002235412598 seconds
# * Owlready * Reparenting object_onto.hasEntityPresented: {object_onto.topContextClassProperty, owl.ObjectProperty} => {object_onto.topContextClassProperty}
# * Owlready * Reparenting object_onto.hasGenericTemperature: {owl.ObjectProperty, object_onto.topClassProperty} => {object_onto.topClassProperty}
# * Owlready * Reparenting object_onto.hasFoodInsideGeneric: {owl.ObjectProperty, object_onto.topClassProperty} => {object_onto.topClassProperty}
# * Owlready * Reparenting object_onto.hasMaterial: {owl.FunctionalProperty, owl.ObjectProperty, object_onto.topClassProperty} => {owl.FunctionalProperty, object_onto.topClassProperty}
# * Owlready * Reparenting object_onto.canWithstandTemperature: {owl.ObjectProperty, object_onto.topClassProperty} => {object_onto.topClassProperty}
# * Owlready * (NB: only changes on entities loaded in Python are shown, other changes are done but not listed)

# %% [markdown]
# ## Base Knowledge Graph
# Now let's see what the base skeleton knowledge graph looks like for a single video. A simple concatenation to grab all edges.

# %%
graph = utils.sentence_to_graph(preds[0], token2tag)
sentences = []
print(len(preds))
for i in range(1, len(preds)-50):
    start_frame_no, end_frame_no = frames_no[i]
    pred, true = preds[i], trues[i]
    if pred not in sentences:
        sentences.append(pred)
        
    graph_curr = utils.sentence_to_graph(preds[i], token2tag)
    for edge in graph_curr:
        if edge not in graph:
            graph.append(edge)
            
print('Base Knowledge Graph:', graph)
print(sentences)
e = visualize.convert_to_graphviz(graph, engine='dot')
e
# Out:
# 111
# Base Knowledge Graph: [('Wamarm', 'V2C_EMPTY_MOVE', 'none'), ('Wamarm', 'V2C_HOLD', 'MilkCan'), ('Wamarm', 'V2C_POUR', 'ColdMilk'), ('MilkCan', 'V2C_FROM', 'ColdMilk'), ('ColdMilk', 'V2C_TO', 'CentricMug')]
# ['none', 'wamarm empty_move', 'wamarm hold milk_can', 'wamarm pour cold_milk from milk_can to centric_mug']

# %% [markdown]
# ## External Knowledge
# Search for external knowledge from ontology itself.

# %%
# Search ontology, grab external knowledge
graph_from_onto = []
for sentence in sentences:
    graph_from_onto_curr = utils.retrieve_knowledge_graph(sentence, token2tag, onto)
    for edge in graph_from_onto_curr:
        if edge not in graph_from_onto:
            graph_from_onto.append(edge)
print()
print('External Knowledge Graph:')
print('-'*20)
print(graph_from_onto)
# Out:
# External Knowledge Graph:
# --------------------
# [('MilkCan', 'hasFoodInsideGeneric, some', 'Milk'), ('MilkCan', 'hasMaterial, some', 'Paper'), ('MilkCan', 'subclass_of', 'Can'), ('MilkCan', 'isGraspableBy, some', 'HumanHand'), ('MilkCan', 'isGraspableBy, some', 'KinovaArm'), ('MilkCan', 'isGraspableBy, some', 'WAMArm'), ('Can', 'has_subclass', 'MilkCan'), ('HumanHand', 'canGrasp, some', 'MilkCan'), ('KinovaArm', 'canGrasp, some', 'MilkCan'), ('WAMArm', 'canGrasp, some', 'MilkCan'), ('ColdMilk', 'hasGenericTemperature, some', 'Cold'), ('ColdMilk', 'subclass_of', 'Milk'), ('Milk', 'has_subclass', 'ColdMilk'), ('CentricMug', 'hasMaterial, some', 'Centric'), ('CentricMug', 'subclass_of', 'Mug'), ('CentricMug', 'isGraspableBy, some', 'HumanHand'), ('CentricMug', 'isGraspableBy, some', 'KinovaArm'), ('CentricMug', 'isGraspableBy, some', 'WAMArm'), ('CentricMug', 'has_individual', 'CentricMug1'), ('CentricMug', 'has_individual', 'CentricMug2'), ('CentricMug', 'has_individual', 'CentricMug3'), ('CentricMug', 'has_individual', 'CentricMug4'), ('Mug', 'has_subclass', 'CentricMug'), ('HumanHand', 'canGrasp, some', 'CentricMug'), ('KinovaArm', 'canGrasp, some', 'CentricMug'), ('WAMArm', 'canGrasp, some', 'CentricMug')]

# %%
e = visualize.convert_to_graphviz(graph_from_onto + graph, engine='sfdp')
e.view()    # Save knowledge graph as a pdf
e
